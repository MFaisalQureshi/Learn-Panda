# %%
import pandas as pd
df=pd.read_csv('wetherdata.csv')
df
# Out:
#      Date  Temperature  Windspead  Event
# 0  1-2-21         20.0       30.0  Sunny
# 1  2-2-21         10.0       20.0   Snow
# 2  3-2-21         15.0       40.0   Rain
# 3  4–2-21         18.0       35.0    NaN
# 4  5-2-21          NaN       30.0  Sunny
# 5  6-2-21          NaN        NaN   Rain
# 6  7-2-21         20.0       10.0   Snow
# 7  8-2-21         10.0        NaN    NaN

# %%
newdf=df.fillna(0)
newdf
# Out:
#      Date  Temperature  Windspead  Event
# 0  1-2-21         20.0       30.0  Sunny
# 1  2-2-21         10.0       20.0   Snow
# 2  3-2-21         15.0       40.0   Rain
# 3  4–2-21         18.0       35.0      0
# 4  5-2-21          0.0       30.0  Sunny
# 5  6-2-21          0.0        0.0   Rain
# 6  7-2-21         20.0       10.0   Snow
# 7  8-2-21         10.0        0.0      0

# %%
newdf=df.fillna(method='ffill')
newdf
# Out:
#      Date  Temperature  Windspead  Event
# 0  1-2-21         20.0       30.0  Sunny
# 1  2-2-21         10.0       20.0   Snow
# 2  3-2-21         15.0       40.0   Rain
# 3  4–2-21         18.0       35.0   Rain
# 4  5-2-21         18.0       30.0  Sunny
# 5  6-2-21         18.0       30.0   Rain
# 6  7-2-21         20.0       10.0   Snow
# 7  8-2-21         10.0       10.0   Snow

# %%
newdf=df.fillna(method='bfill')
newdf
# Out:
#      Date  Temperature  Windspead  Event
# 0  1-2-21         20.0       30.0  Sunny
# 1  2-2-21         10.0       20.0   Snow
# 2  3-2-21         15.0       40.0   Rain
# 3  4–2-21         18.0       35.0  Sunny
# 4  5-2-21         20.0       30.0  Sunny
# 5  6-2-21         20.0       10.0   Rain
# 6  7-2-21         20.0       10.0   Snow
# 7  8-2-21         10.0        NaN    NaN

# %%
newdf=df.fillna(method='ffill',axis='rows')
newdf
# Out:
#      Date  Temperature  Windspead  Event
# 0  1-2-21         20.0       30.0  Sunny
# 1  2-2-21         10.0       20.0   Snow
# 2  3-2-21         15.0       40.0   Rain
# 3  4–2-21         18.0       35.0   Rain
# 4  5-2-21         18.0       30.0  Sunny
# 5  6-2-21         18.0       30.0   Rain
# 6  7-2-21         20.0       10.0   Snow
# 7  8-2-21         10.0       10.0   Snow

# %%
newdf=df.fillna(method='ffill',limit=1)
newdf
# Out:
#      Date  Temperature  Windspead  Event
# 0  1-2-21         20.0       30.0  Sunny
# 1  2-2-21         10.0       20.0   Snow
# 2  3-2-21         15.0       40.0   Rain
# 3  4–2-21         18.0       35.0   Rain
# 4  5-2-21         18.0       30.0  Sunny
# 5  6-2-21          NaN       30.0   Rain
# 6  7-2-21         20.0       10.0   Snow
# 7  8-2-21         10.0       10.0   Snow

# %%
newdf=df.interpolate()
newdf
# Out:
#      Date  Temperature  Windspead  Event
# 0  1-2-21    20.000000       30.0  Sunny
# 1  2-2-21    10.000000       20.0   Snow
# 2  3-2-21    15.000000       40.0   Rain
# 3  4–2-21    18.000000       35.0    NaN
# 4  5-2-21    18.666667       30.0  Sunny
# 5  6-2-21    19.333333       20.0   Rain
# 6  7-2-21    20.000000       10.0   Snow
# 7  8-2-21    10.000000       10.0    NaN

# %%
df
# Out:
#      Date  Temperature  Windspead  Event
# 0  1-2-21         20.0       30.0  Sunny
# 1  2-2-21         10.0       20.0   Snow
# 2  3-2-21         15.0       40.0   Rain
# 3  4–2-21         18.0       35.0    NaN
# 4  5-2-21          NaN       30.0  Sunny
# 5  6-2-21          NaN        NaN   Rain
# 6  7-2-21         20.0       10.0   Snow
# 7  8-2-21         10.0        NaN    NaN

# %%
newdf=pd.read_csv('wetherdata.csv',parse_dates=['Date'])
newdf.set_index('Date',inplace=True)
newdf
# Out:
#         Temperature  Windspead  Event
# Date
# 1-2-21         20.0       30.0  Sunny
# 2-2-21         10.0       20.0   Snow
# 3-2-21         15.0       40.0   Rain
# 4–2-21         18.0       35.0    NaN
# 5-2-21          NaN       30.0  Sunny
# 6-2-21          NaN        NaN   Rain
# 7-2-21         20.0       10.0   Snow
# 8-2-21         10.0        NaN    NaN

# %%
# If any row contain 1 valid value than show the row 
newdf=df.dropna(thresh=1)
newdf
# Out:
#         Temperature  Windspead  Event
# Date
# 1-2-21         20.0       30.0  Sunny
# 2-2-21         10.0       20.0   Snow
# 3-2-21         15.0       40.0   Rain
# 4–2-21         18.0       35.0    NaN
# 5-2-21          NaN       30.0  Sunny
# 6-2-21          NaN        NaN   Rain
# 7-2-21         20.0       10.0   Snow
# 8-2-21         10.0        NaN    NaN

# %%
# If any row contain 2 valid value than show the row 
newdf=df.dropna(thresh=2)
newdf
# Out:
#         Temperature  Windspead  Event
# Date
# 1-2-21         20.0       30.0  Sunny
# 2-2-21         10.0       20.0   Snow
# 3-2-21         15.0       40.0   Rain
# 4–2-21         18.0       35.0    NaN
# 5-2-21          NaN       30.0  Sunny
# 7-2-21         20.0       10.0   Snow
