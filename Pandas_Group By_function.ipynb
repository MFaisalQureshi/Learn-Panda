# %%
import pandas as pd
df=pd.read_csv('weathercity.csv')
df
# Out:
#          day       city  temperature  windspead   event
# 0   01/01/21    Karachi           30          5   sunny
# 1   02/01/21    Karachi           32          8  cloudy
# 2   03/01/21    Karachi           36         10   sunny
# 3   04/01/21    Karachi           38          6  cloudy
# 4   05/01/21     Lahore           22         12  cloudy
# 5   06/01/21     Lahore           25         15    rain
# 6   07/01/21     Lahore           28         10    rain
# 7   08/01/21     Lahore           30         11   sunny
# 8   09/01/21  Islamabad           20          8    rain
# 9   10/01/21  Islamabad           18          6  cloudy
# 10  11/01/21  Islamabad           22          7    rain
# 11  11/01/21  Islamabad           25          9   sunny

# %%
group=df.groupby('city')
group

# %%
for city,citydf in group:
    print(city)
    print(citydf)
# Out:
# Islamabad
#          day       city  temperature  windspead   event
# 8   09/01/21  Islamabad           20          8    rain
# 9   10/01/21  Islamabad           18          6  cloudy
# 10  11/01/21  Islamabad           22          7    rain
# 11  11/01/21  Islamabad           25          9   sunny
# Karachi
#         day     city  temperature  windspead   event
# 0  01/01/21  Karachi           30          5   sunny
# 1  02/01/21  Karachi           32          8  cloudy
# 2  03/01/21  Karachi           36         10   sunny
# 3  04/01/21  Karachi           38          6  cloudy
# Lahore
#         day    city  temperature  windspead   event
# 4  05/01/21  Lahore           22         12  cloudy
# 5  06/01/21  Lahore           25         15    rain
# 6  07/01/21  Lahore           28         10    rain
# 7  08/01/21  Lahore           30         11   sunny

# %%
group.get_group('Karachi')
# Out:
#         day     city  temperature  windspead   event
# 0  01/01/21  Karachi           30          5   sunny
# 1  02/01/21  Karachi           32          8  cloudy
# 2  03/01/21  Karachi           36         10   sunny
# 3  04/01/21  Karachi           38          6  cloudy

# %%
group.max()
# Out:
#                 day  temperature  windspead  event
# city
# Islamabad  11/01/21           25          9  sunny
# Karachi    04/01/21           38         10  sunny
# Lahore     08/01/21           30         15  sunny

# %%
group.mean('Islamabad')
# Out:
#            temperature  windspead
# city
# Islamabad        21.25       7.50
# Karachi          34.00       7.25
# Lahore           26.25      12.00

# %%
# %matplotlib inline
group.plot()
# Out:
# city
# Islamabad    AxesSubplot(0.125,0.125;0.775x0.755)
# Karachi      AxesSubplot(0.125,0.125;0.775x0.755)
# Lahore       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
group.median()
# Out:
#            temperature  windspead
# city
# Islamabad         21.0        7.5
# Karachi           34.0        7.0
# Lahore            26.5       11.5
